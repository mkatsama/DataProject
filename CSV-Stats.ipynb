# %%
import pandas as pd

# %%
#2020/2021
dataset1 = pd.read_csv(r'Desktop/CSVFILEFOOT/2020-2021.csv')
player1 = dataset1.loc[dataset1['full_name'].str.contains("Santos Gato", case = False) ]
player1
# Out:
#                         full_name  age   birthday birthday_GMT  \
# 538  Rúben Santos Gato Alves Dias   24  863568000   1997/05/14
#
#              league     season  position     Current Club  \
# 538  Premier League  2020/2021  Defender  Manchester City
#
#      minutes_played_overall  minutes_played_home  ...  \
# 538                    2845                 1420  ...
#
#      conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 538                      0.6                      150             89
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 538                   711                       0                  0.13
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 538                           258                             282
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 538                             5                       14
#
# [1 rows x 47 columns]

# %%
#2019/2020
dataset2 = pd.read_csv(r'Desktop/CSVFILEFOOT/2019-2020.csv')
player2 = dataset2.loc[dataset2['full_name'].str.contains("De Bruyne", case = False) ]
df2 = dataset2.iloc[:,0:20]
df2.head()
# Out:
#                 full_name  age   birthday birthday_GMT          league  \
# 0  Aaron Anthony Connolly   21  949017600   2000/01/28  Premier League
# 1         Aaron Cresswell   32  629683200   1989/12/15  Premier League
# 2            Aaron Lennon   34  545529600   1987/04/16  Premier League
# 3              Aaron Mooy   31  653356800   1990/09/15  Premier League
# 4          Aaron Ramsdale   23  895104000   1998/05/14  Premier League
#
#       season    position            Current Club  minutes_played_overall  \
# 0  2019/2020     Forward  Brighton & Hove Albion                    1262
# 1  2019/2020    Defender         West Ham United                    2730
# 2  2019/2020  Midfielder                 Burnley                     485
# 3  2019/2020  Midfielder  Brighton & Hove Albion                    2090
# 4  2019/2020  Goalkeeper         AFC Bournemouth                    3330
#
#    minutes_played_home  minutes_played_away          nationality  \
# ...

# %%
#2018/2019
dataset3 = pd.read_csv(r'Desktop/CSVFILEFOOT/2018-2019.csv')
player3 = dataset3.loc[dataset3['full_name'].str.contains("Virgil", case = False) ]
player3
# Out:
#            full_name  age   birthday birthday_GMT          league     season  \
# 553  Virgil van Dijk   30  678931200   1991/07/08  Premier League  2018/2019
#
#      position Current Club  minutes_played_overall  minutes_played_home  ...  \
# 553  Defender    Liverpool                    3385                 1675  ...
#
#      conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 553                     0.51                      178             89
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 553                  3385                    1693                  0.03
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 553                           152                             201
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 553                             5                        6
#
# [1 rows x 47 columns]

# %%
#2017/2018
dataset4 = pd.read_csv(r'Desktop/CSVFILEFOOT/2017-2018.csv')
player4 = dataset4.loc[dataset4['full_name'].str.contains("Salah", case = False) ]
player4
# Out:
#          full_name  age   birthday birthday_GMT          league     season  \
# 427  Mohamed Salah   29  708566400   1992/06/15  Premier League  2017/2018
#
#     position Current Club  minutes_played_overall  minutes_played_home  ...  \
# 427  Forward    Liverpool                    2922                 1556  ...
#
#      conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 427                     0.89                      101             81
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 427                  2922                     292                  0.03
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 427                             1                              16
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 427                            -1                        1
#
# [1 rows x 47 columns]

# %%
#2016/2017
dataset5 = pd.read_csv(r'Desktop/CSVFILEFOOT/2016-2017.csv')
player5 = dataset5.loc[dataset5['full_name'].str.contains("N'Golo", case = False) ]
player5
# Out:
#         full_name  age   birthday birthday_GMT          league     season  \
# 452  N'Golo Kanté   30  670204800   1991/03/29  Premier League  2016/2017
#
#        position Current Club  minutes_played_overall  minutes_played_home  \
# 452  Midfielder      Chelsea                    3139                 1530
#
#      ...  conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 452  ...                     0.86                      105             90
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 452                   349                    3139                  0.26
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 452                           256                             228
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 452                            -1                       11
#
# [1 rows x 47 columns]

# %%
#2015/2016
dataset6 = pd.read_csv(r'Desktop/CSVFILEFOOT/2015-2016.csv')
player6 = dataset6.loc[dataset6['full_name'].str.contains("Vardy", case = False) ]
player6
# Out:
#        full_name  age   birthday birthday_GMT          league     season  \
# 266  Jamie Vardy   34  537321600   1987/01/11  Premier League  2015/2016
#
#     position    Current Club  minutes_played_overall  minutes_played_home  \
# 266  Forward  Leicester City                    3140                 1576
#
#      ...  conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 266  ...                     0.86                      105             87
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 266                   449                     523                   0.2
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 266                             4                              83
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 266                            -1                        1
#
# [1 rows x 47 columns]

# %%
#2014/2015
dataset7 = pd.read_csv(r'Desktop/CSVFILEFOOT/2014-2015.csv')
player7 = dataset7.loc[dataset7['full_name'].str.contains("Hazard", case = False) ]
player7
# Out:
#        full_name  age   birthday birthday_GMT          league     season  \
# 168  Eden Hazard   31  663206400   1991/01/07  Premier League  2014/2015
#
#        position Current Club  minutes_played_overall  minutes_played_home  \
# 168  Midfielder      Chelsea                    3379                 1688
#
#      ...  conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 168  ...                      0.8                      113             89
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 168                  1690                     375                  0.05
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 168                            38                              37
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 168                            -1                        2
#
# [1 rows x 47 columns]

# %%
#2013/2014
dataset8 = pd.read_csv(r'Desktop/CSVFILEFOOT/2013-2014.csv')
player8 = dataset8.loc[dataset8['full_name'].str.contains("Suárez", case = False) ]
player8
# Out:
#        full_name  age   birthday birthday_GMT          league     season  \
# 366  Luis Suárez   34  538444800   1987/01/24  Premier League  2013/2014
#
#     position Current Club  minutes_played_overall  minutes_played_home  ...  \
# 366  Forward    Liverpool                    2964                 1434  ...
#
#      conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 366                      1.4                       64             90
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 366                   494                     247                  0.18
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 366                             2                              12
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 366                            -1                        1
#
# [1 rows x 47 columns]

# %%
#2012/2013
dataset9 = pd.read_csv(r'Desktop/CSVFILEFOOT/2012-2013.csv')
player9 = dataset9.loc[dataset9['full_name'].str.contains("Gareth Bale", case = False) ]
player9
# Out:
#        full_name  age   birthday birthday_GMT          league     season  \
# 193  Gareth Bale   32  616550400   1989/07/16  Premier League  2012/2013
#
#     position       Current Club  minutes_played_overall  minutes_played_home  \
# 193  Forward  Tottenham Hotspur                    2925                 1350
#
#      ...  conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 193  ...                     1.05                       86             89
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 193                   488                     731                  0.18
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 193                             9                             124
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 193                            -1                        1
#
# [1 rows x 47 columns]

# %%
#2011/2012
dataset10 = pd.read_csv(r'Desktop/CSVFILEFOOT/2011-2012.csv')
player10 = dataset10.loc[dataset10['full_name'].str.contains("Vincent Kompany", case = False) ]
player10
# Out:
#            full_name  age   birthday birthday_GMT          league     season  \
# 604  Vincent Kompany   35  513475200   1986/04/10  Premier League  2011/2012
#
#      position     Current Club  minutes_played_overall  minutes_played_home  \
# 604  Defender  Manchester City                    2774                 1424
#
#      ...  conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 604  ...                     0.65                      139             89
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 604                   396                    1387                  0.23
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 604                           170                             228
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 604                             8                        9
#
# [1 rows x 47 columns]

# %%
#2010/2011
dataset11 = pd.read_csv(r'Desktop/CSVFILEFOOT/2010-2011.csv')
player11 = dataset11.loc[dataset11['full_name'].str.contains("Wayne Rooney", case = False) ]
player11
# Out:
#         full_name  age   birthday birthday_GMT          league     season  \
# 614  Wayne Rooney   36  498960000   1985/10/24  Premier League  2010/2011
#
#     position       Current Club  minutes_played_overall  minutes_played_home  \
# 614  Forward  Manchester United                    2228                 1112
#
#      ...  conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 614  ...                     0.85                      106             80
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 614                   446                     223                   0.2
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 614                            30                              13
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 614                            -1                        3
#
# [1 rows x 47 columns]

# %%
#2009/2010
dataset12 = pd.read_csv(r'Desktop/CSVFILEFOOT/2009-2010.csv')
player12 = dataset12.loc[dataset12['full_name'].str.contains("Vidić", case = False) ]
player12
# Out:
#          full_name  age   birthday birthday_GMT          league     season  \
# 444  Nemanja Vidić   40  372470400   1981/10/21  Premier League  2009/2010
#
#      position       Current Club  minutes_played_overall  minutes_played_home  \
# 444  Defender  Manchester United                    2107                 1118
#
#      ...  conceded_per_90_overall min_per_conceded_overall  min_per_match  \
# 444  ...                      0.6                      151             88
#
#      min_per_card_overall  min_per_assist_overall  cards_per_90_overall  \
# 444                   234                       0                  0.38
#
#      rank_in_league_top_attackers  rank_in_league_top_midfielders  \
# 444                           239                             308
#
#      rank_in_league_top_defenders  rank_in_club_top_scorer
# 444                             7                       15
#
# [1 rows x 47 columns]

# %%
fulldata = [player1, player2, player3, player4, player5, player6, player7, player8, player9, player10, player11, player12]
fulldataframe = pd.concat(fulldata)
fulldataframe
fulldataframe.iloc[:,0:20]
Average = fulldataframe['minutes_played_overall'].mean()
Max = fulldataframe['minutes_played_overall'].max()
Min = fulldataframe['minutes_played_overall'].min()
print(Average)
fulldataframe
# Out:
# 2884.0
#                         full_name  age   birthday birthday_GMT  \
# 538  Rúben Santos Gato Alves Dias   24  863568000   1997/05/14
# 349               Kevin De Bruyne   30  678067200   1991/06/28
# 553               Virgil van Dijk   30  678931200   1991/07/08
# 427                 Mohamed Salah   29  708566400   1992/06/15
# 452                  N'Golo Kanté   30  670204800   1991/03/29
# 266                   Jamie Vardy   34  537321600   1987/01/11
# 168                   Eden Hazard   31  663206400   1991/01/07
# 366                   Luis Suárez   34  538444800   1987/01/24
# 193                   Gareth Bale   32  616550400   1989/07/16
# 604               Vincent Kompany   35  513475200   1986/04/10
# 614                  Wayne Rooney   36  498960000   1985/10/24
# 444                 Nemanja Vidić   40  372470400   1981/10/21
#
#              league     season    position       Current Club  \
# 538  Premier League  2020/2021    Defender    Manchester City
# ...

# %%
#Defender DataFrame
defenders = fulldataframe.loc[fulldataframe['position'].str.contains("Defender", case = False) ]
defenders.to_csv(r'Desktop/CSVFILEFOOT/DEFENDER.csv')
#Average cleansheets, conceded goals
DCleanAverage = defenders['clean_sheets_overall'].mean()
DConcededAverage = defenders['conceded_overall'].mean()
print(DCleanAverage)
print(DConcededAverage)
defenders.iloc[:, :26]
defenders
# Out:
# 16.5
# 18.0
#                         full_name  age   birthday birthday_GMT  \
# 538  Rúben Santos Gato Alves Dias   24  863568000   1997/05/14
# 553               Virgil van Dijk   30  678931200   1991/07/08
# 604               Vincent Kompany   35  513475200   1986/04/10
# 444                 Nemanja Vidić   40  372470400   1981/10/21
#
#              league     season  position       Current Club  \
# 538  Premier League  2020/2021  Defender    Manchester City
# 553  Premier League  2018/2019  Defender          Liverpool
# 604  Premier League  2011/2012  Defender    Manchester City
# 444  Premier League  2009/2010  Defender  Manchester United
#
#      minutes_played_overall  minutes_played_home  ...  \
# 538                    2845                 1420  ...
# 553                    3385                 1675  ...
# 604                    2774                 1424  ...
# 444                    2107                 1118  ...
#
# ...

# %%
#Forward DataFrame
forwards = fulldataframe.loc[fulldataframe['position'].str.contains("Forward", case = False) ]
real = forwards.iloc[0:4,0:26]
real['']
# Out:
#          full_name  age   birthday birthday_GMT          league     season  \
# 427  Mohamed Salah   29  708566400   1992/06/15  Premier League  2017/2018
# 266    Jamie Vardy   34  537321600   1987/01/11  Premier League  2015/2016
# 366    Luis Suárez   34  538444800   1987/01/24  Premier League  2013/2014
# 193    Gareth Bale   32  616550400   1989/07/16  Premier League  2012/2013
#
#     position       Current Club  minutes_played_overall  minutes_played_home  \
# 427  Forward          Liverpool                    2922                 1556
# 266  Forward     Leicester City                    3140                 1576
# 366  Forward          Liverpool                    2964                 1434
# 193  Forward  Tottenham Hotspur                    2925                 1350
#
#      ...  goals_home goals_away  assists_overall  assists_home  assists_away  \
# 427  ...          19         13               10             8             2
# ...

# %%
#Midfielder DataFrame
Midfielders = fulldataframe.loc[fulldataframe['position'].str.contains("Midfielder", case = False) ]
Midfielders.iloc[:,0:26]
MCleanAverage = Midfielders['assists_overall'].mean()
MCleanAverage
# Out:
# 10.0
