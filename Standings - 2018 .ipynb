# %%
import pandas as pd 
import requests
import json 

url = "https://api-football-v1.p.rapidapi.com/v3/standings"

querystring = {"league":"39","season":"2018"}

headers = {
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com",
	"X-RapidAPI-Key": "ecad4fe8femsh2bf7c9cd0fe9bedp159909jsn0f8655e543b0"
}

resp = requests.request("GET", url, headers=headers, params=querystring)

print(resp.text)
# Out:
# {"get":"standings","parameters":{"league":"39","season":"2018"},"errors":[],"results":1,"paging":{"current":1,"total":1},"response":[{"league":{"id":39,"name":"Premier League","country":"England","logo":"https:\/\/media.api-sports.io\/football\/leagues\/39.png","flag":"https:\/\/media.api-sports.io\/flags\/gb.svg","season":2018,"standings":[[{"rank":1,"team":{"id":50,"name":"Manchester City","logo":"https:\/\/media.api-sports.io\/football\/teams\/50.png"},"points":98,"goalsDiff":72,"group":"Premier League","form":"WWWWW","status":null,"description":"Promotion - Champions League (Group Stage)","all":{"played":38,"win":32,"draw":2,"lose":4,"goals":{"for":95,"against":23}},"home":{"played":19,"win":18,"draw":0,"lose":1,"goals":{"for":57,"against":12}},"away":{"played":19,"win":14,"draw":2,"lose":3,"goals":{"for":38,"against":11}},"update":"2019-05-12T00:00:00+00:00"},{"rank":2,"team":{"id":40,"name":"Liverpool","logo":"https:\/\/media.api-sports.io\/football\/teams\/40.png"},"points":97,"goalsDiff":67,"group":"Premier League","form":"WWWWW","status":null,"description":"Promotion - Champions League (Group Stage)","all":{"played":38,"win":30,"draw":7,"lose":1,"goals":{"for":89,"against":22}},"home":{"played":19,"win":17,"draw":2,"lose":0,"goals":{"for":55,"against":10}},"away":{"played":19,"win":13,"draw":5,"lose":1,"goals":{"for":34,"against":12}},"update":"2019-05-12T00:00:00+00:00"},{"rank":3,"team":{"id":49,"name":"Chelsea","logo":"https:\/\/media.api-sports.io\/football\/teams\/49.png"},"points":72,"goalsDiff":24,"group":"Premier League","form":"DWDDL","status":null,"description":"Promotion - Champions League (Group Stage)","all":{"played":38,"win":21,"draw":9,"lose":8,"goals":{"for":63,"against":39}},"home":{"played":19,"win":12,"draw":6,"lose":1,"goals":{"for":39,"against":12}},"away":{"played":19,"win":9,"draw":3,"lose":7,"goals":{"for":24,"against":27}},"update":"2019-05-12T00:00:00+00:00"},{"rank":4,"team":{"id":47,"name":"Tottenham","logo":"https:\/\/media.api-sports.io\/football\/teams\/47.png"},"points":71,"goalsDiff":28,"group":"Premier League","form":"DLLWL","status":null,"description":"Promotion - Champions League (Group Stage)","all":{"played":38,"win":23,"draw":2,"lose":13,"goals":{"for":67,"against":39}},"home":{"played":19,"win":12,"draw":2,"lose":5,"goals":{"for":34,"against":16}},"away":{"played":19,"win":11,"draw":0,"lose":8,"goals":{"for":33,"against":23}},"update":"2019-05-12T00:00:00+00:00"},{"rank":5,"team":{"id":42,"name":"Arsenal","logo":"https:\/\/media.api-sports.io\/football\/teams\/42.png"},"points":70,"goalsDiff":22,"group":"Premier League","form":"WDLLL","status":null,"description":"Promotion - Europa League (Group Stage)","all":{"played":38,"win":21,"draw":7,"lose":10,"goals":{"for":73,"against":51}},"home":{"played":19,"win":14,"draw":3,"lose":2,"goals":{"for":42,"against":16}},"away":{"played":19,"win":7,"draw":4,"lose":8,"goals":{"for":31,"against":35}},"update":"2019-05-12T00:00:00+00:00"},{"rank":6,"team":{"id":33,"name":"Manchester United","logo":"https:\/\/media.api-sports.io\/football\/teams\/33.png"},"points":66,"goalsDiff":11,"group":"Premier League","form":"LDDLL","status":null,"description":"Promotion - Europa League (Qualification)","all":{"played":38,"win":19,"draw":9,"lose":10,"goals":{"for":65,"against":54}},"home":{"played":19,"win":10,"draw":6,"lose":3,"goals":{"for":33,"against":25}},"away":{"played":19,"win":9,"draw":3,"lose":7,"goals":{"for":32,"against":29}},"update":"2019-05-12T00:00:00+00:00"},{"rank":7,"team":{"id":39,"name":"Wolves","logo":"https:\/\/media.api-sports.io\/football\/teams\/39.png"},"points":57,"goalsDiff":1,"group":"Premier League","form":"LWWWD","status":null,"description":null,"all":{"played":38,"win":16,"draw":9,"lose":13,"goals":{"for":47,"against":46}},"home":{"played":19,"win":10,"draw":4,"lose":5,"goals":{"for":28,"against":21}},"away":{"played":19,"win":6,"draw":5,"lose":8,"goals":{"for":19,"against":25}},"update":"2019-05-12T00:00:00+00:00"},{"ran ...

# %%
data = resp.json()
df = pd.DataFrame(data['response'][0]['league']['standings'][0])
df.index = df.index + 1
df
# Out:
#     rank                                               team  points  \
# 1      1  {'id': 50, 'name': 'Manchester City', 'logo': ...      98
# 2      2  {'id': 40, 'name': 'Liverpool', 'logo': 'https...      97
# 3      3  {'id': 49, 'name': 'Chelsea', 'logo': 'https:/...      72
# 4      4  {'id': 47, 'name': 'Tottenham', 'logo': 'https...      71
# 5      5  {'id': 42, 'name': 'Arsenal', 'logo': 'https:/...      70
# 6      6  {'id': 33, 'name': 'Manchester United', 'logo'...      66
# 7      7  {'id': 39, 'name': 'Wolves', 'logo': 'https://...      57
# 8      8  {'id': 45, 'name': 'Everton', 'logo': 'https:/...      54
# 9      9  {'id': 46, 'name': 'Leicester', 'logo': 'https...      52
# 10    10  {'id': 48, 'name': 'West Ham', 'logo': 'https:...      52
# 11    11  {'id': 38, 'name': 'Watford', 'logo': 'https:/...      50
# 12    12  {'id': 52, 'name': 'Crystal Palace', 'logo': '...      49
# 13    13  {'id': 34, 'name': 'Newcastle', 'logo': 'https...      45
# 14    14  {'id': 35, 'name': 'Bournemouth', 'logo': 'htt...      45
# 15    15  {'id': 44, 'name': 'Burnley', 'logo': 'https:/...      40
# 16    16  {'id': 41, 'name': 'Southampton', 'logo': 'htt...      39
# 17    17  {'id': 51, 'name': 'Brighton', 'logo': 'https:...      36
# 18    18  {'id': 43, 'name': 'Cardiff', 'logo': 'https:/...      34
# 19    19  {'id': 36, 'name': 'Fulham', 'logo': 'https://...      26
# 20    20  {'id': 37, 'name': 'Huddersfield', 'logo': 'ht...      16
#
#     goalsDiff           group   form status  \
# 1          72  Premier League  WWWWW   None
# 2          67  Premier League  WWWWW   None
# 3          24  Premier League  DWDDL   None
# 4          28  Premier League  DLLWL   None
# 5          22  Premier League  WDLLL   None
# 6          11  Premier League  LDDLL   None
# 7           1  Premier League  LWWWD   None
# 8           8  Premier League  DWDWL   None
# 9           3  Premier League  DLWDL   None
# 10         -3  Premier League  WWWDL   None
# 11         -7  Premier League  LLLDW   None
# 12         -2  Premier League  WWDWL   None
# 13         -6  Premier League  WLDWW   None
# 14        -14  Premier League  LWDLW   None
# 15        -23  Premier League  LLLDW   None
# 16        -20  Premier League  DLDDL   None
# 17        -25  Premier League  LDDLD   None
# 18        -35  Premier League  WLLLW   None
# 19        -47  Premier League  LLWWW   None
# 20        -54  Premier League  DDLLL   None
#
#                                    description  \
# 1   Promotion - Champions League (Group Stage)
# 2   Promotion - Champions League (Group Stage)
# 3   Promotion - Champions League (Group Stage)
# 4   Promotion - Champions League (Group Stage)
# 5      Promotion - Europa League (Group Stage)
# 6    Promotion - Europa League (Qualification)
# 7                                         None
# 8                                         None
# 9                                         None
# 10                                        None
# 11                                        None
# 12                                        None
# 13                                        None
# 14                                        None
# 15                                        None
# 16                                        None
# 17                                        None
# 18                   Relegation - Championship
# 19                   Relegation - Championship
# 20                   Relegation - Championship
#
#                                                   all  \
# 1   {'played': 38, 'win': 32, 'draw': 2, 'lose': 4...
# 2   {'played': 38, 'win': 30, 'draw': 7, 'lose': 1...
# 3   {'played': 38, 'win': 21, 'draw': 9, 'lose': 8...
# 4   {'played': 38, 'win': 23, 'draw': 2, 'lose': 1...
# 5   {'played': 38, 'win': 21, 'draw': 7, 'lose': 1...
# 6   {'played': 38, 'win': 19, 'draw': 9, 'lose': 1...
# 7   {'played': 38, 'win': 16, 'draw': 9, 'lose': 1...
# 8   {'played': 38, 'win': 15, 'draw': 9, 'lose': 1...
# 9   {'played': 38, 'win': 15, 'draw': 7, 'lose': 1...
# 10  {'played': 38, 'win': 15, 'draw': 7, 'lose': 1...
# 11  {'played': 38, 'win': 14, 'draw': 8, 'lose': 1...
# 12  {'played': 38, 'win': 14, 'draw': 7, 'lose': 1...
# 13  {'played': 38, 'win': 12, 'draw': 9, 'lose': 1...
# 14  {'played': 38, 'win': 13, 'draw': 6, 'lose': 1...
# 15  {'played': 38, 'win': 11, 'draw': 7, 'lose': 2...
# 16  {'played': 38, 'win': 9, 'draw': 12, 'lose': 1...
# 17  {'played': 38, 'win': 9, 'draw': 9, 'lose': 20...
# 18  {'played': 38, 'win': 10, 'draw': 4, 'lose': 2...
# 19  {'played': 38, 'win': 7, 'draw': 5, 'lose': 26...
# 20  {'played': 38, 'win': 3, 'draw': 7, 'lose': 28...
#
#                                                  home  \
# 1   {'played': 19, 'win': 18, 'draw': 0, 'lose': 1...
# 2   {'played': 19, 'win': 17, 'draw': 2, 'lose': 0...
# 3   {'played': 19, 'win': 12, 'draw': 6, 'lose': 1...
# 4   {'played': 19, 'win': 12, 'draw': 2, 'lose': 5...
# 5   {'played': 19, 'win': 14, 'draw': 3, 'lose': 2...
# 6   {'played': 19, 'win': 10, 'draw': 6, 'lose': 3...
# 7   {'played': 19, 'win': 10, 'draw': 4, 'lose': 5...
# 8   {'played': 19, 'win': 10, 'draw': 4, 'lose': 5...
# 9   {'played': 19, 'win': 8, 'draw': 3, 'lose': 8,...
# 10  {'played': 19, 'win': 9, 'draw': 4, 'lose': 6,...
# 11  {'played': 19, 'win': 8, 'draw': 3, 'lose': 8,...
# 12  {'played': 19, 'win': 5, 'draw': 5, 'lose': 9,...
# 13  {'played': 19, 'win': 8, 'draw': 1, 'lose': 10...
# 14  {'played': 19, 'win': 8, 'draw': 5, 'lose': 6,...
# 15  {'played': 19, 'win': 7, 'draw': 2, 'lose': 10...
# 16  {'played': 19, 'win': 5, 'draw': 8, 'lose': 6,...
# 17  {'played': 19, 'win': 6, 'draw': 5, 'lose': 8,...
# 18  {'played': 19, 'win': 6, 'draw': 2, 'lose': 11...
# 19  {'played': 19, 'win': 6, 'draw': 3, 'lose': 10...
# 20  {'played': 19, 'win': 2, 'draw': 3, 'lose': 14...
#
#                                                  away  \
# 1   {'played': 19, 'win': 14, 'draw': 2, 'lose': 3...
# 2   {'played': 19, 'win': 13, 'draw': 5, 'lose': 1...
# 3   {'played': 19, 'win': 9, 'draw': 3, 'lose': 7,...
# 4   {'played': 19, 'win': 11, 'draw': 0, 'lose': 8...
# 5   {'played': 19, 'win': 7, 'draw': 4, 'lose': 8,...
# 6   {'played': 19, 'win': 9, 'draw': 3, 'lose': 7,...
# 7   {'played': 19, 'win': 6, 'draw': 5, 'lose': 8,...
# 8   {'played': 19, 'win': 5, 'draw': 5, 'lose': 9,...
# 9   {'played': 19, 'win': 7, 'draw': 4, 'lose': 8,...
# 10  {'played': 19, 'win': 6, 'draw': 3, 'lose': 10...
# 11  {'played': 19, 'win': 6, 'draw': 5, 'lose': 8,...
# 12  {'played': 19, 'win': 9, 'draw': 2, 'lose': 8,...
# 13  {'played': 19, 'win': 4, 'draw': 8, 'lose': 7,...
# 14  {'played': 19, 'win': 5, 'draw': 1, 'lose': 13...
# 15  {'played': 19, 'win': 4, 'draw': 5, 'lose': 10...
# 16  {'played': 19, 'win': 4, 'draw': 4, 'lose': 11...
# 17  {'played': 19, 'win': 3, 'draw': 4, 'lose': 12...
# 18  {'played': 19, 'win': 4, 'draw': 2, 'lose': 13...
# 19  {'played': 19, 'win': 1, 'draw': 2, 'lose': 16...
# 20  {'played': 19, 'win': 1, 'draw': 4, 'lose': 14...
#
#                        update
# 1   2019-05-12T00:00:00+00:00
# 2   2019-05-12T00:00:00+00:00
# 3   2019-05-12T00:00:00+00:00
# 4   2019-05-12T00:00:00+00:00
# 5   2019-05-12T00:00:00+00:00
# 6   2019-05-12T00:00:00+00:00
# 7   2019-05-12T00:00:00+00:00
# 8   2019-05-12T00:00:00+00:00
# 9   2019-05-12T00:00:00+00:00
# 10  2019-05-12T00:00:00+00:00
# 11  2019-05-12T00:00:00+00:00
# 12  2019-05-12T00:00:00+00:00
# 13  2019-05-12T00:00:00+00:00
# 14  2019-05-12T00:00:00+00:00
# 15  2019-05-12T00:00:00+00:00
# 16  2019-05-12T00:00:00+00:00
# 17  2019-05-12T00:00:00+00:00
# 18  2019-05-12T00:00:00+00:00
# 19  2019-05-12T00:00:00+00:00
# 20  2019-05-12T00:00:00+00:00
